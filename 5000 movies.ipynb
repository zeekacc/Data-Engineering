# %% [markdown]
# ## Problem 15
# ### In order to solve this set of questions you will use the dataset in the relative directory ./Datasets/tmdb_5000_movies.csv

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Open Your CSV file and print the first 10 rows in a good format ###

# %%
dataset = pd.read_csv('./Datasets/tmdb_5000_movies.csv')
dataset.head(10)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# 3                 http://www.thedarkknightrises.com/   49026
# 4               http://movies.disney.com/john-carter   49529
# 5    http://www.sonypictures.com/movies/spider-man3/     559
# 6       http://disney.go.com/disneypictures/tangled/   38757
# 7  http://marvel.com/movies/movie/193/avengers_ag...   99861
# 8  http://harrypotter.warnerbros.com/harrypottera...     767
# 9       http://www.batmanvsupermandawnofjustice.com/  209112
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
# 5  [{"id": 851, "name": "dual identity"}, {"id": ...                en
# 6  [{"id": 1562, "name": "hostage"}, {"id": 2343,...                en
# 7  [{"id": 8828, "name": "marvel comic"}, {"id": ...                en
# 8  [{"id": 616, "name": "witch"}, {"id": 2343, "n...                en
# 9  [{"id": 849, "name": "dc comics"}, {"id": 7002...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
# 5                              Spider-Man 3
# 6                                   Tangled
# 7                   Avengers: Age of Ultron
# 8    Harry Potter and the Half-Blood Prince
# 9        Batman v Superman: Dawn of Justice
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
# 5  The seemingly invincible Spider-Man goes up ag...  115.699814
# 6  When the kingdom's most wanted-and most charmi...   48.681969
# 7  When Tony Stark tries to jumpstart a dormant p...  134.279229
# 8  As Harry begins his sixth year at Hogwarts, he...   98.885637
# 9  Fearing the actions of a god-like Super Hero l...  155.790452
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
# 5  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 6  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 7  [{"name": "Marvel Studios", "id": 420}, {"name...
# 8  [{"name": "Warner Bros.", "id": 6194}, {"name"...
# 9  [{"name": "DC Comics", "id": 429}, {"name": "A...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
# 5  [{"iso_3166_1": "US", "name": "United States o...   2007-05-01   890871626
# 6  [{"iso_3166_1": "US", "name": "United States o...   2010-11-24   591794936
# 7  [{"iso_3166_1": "US", "name": "United States o...   2015-04-22  1405403694
# 8  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2009-07-07   933959197
# 9  [{"iso_3166_1": "US", "name": "United States o...   2016-03-23   873260194
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 5    139.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 6    100.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 7    141.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 8    153.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 9    151.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
# 5                              The battle within.
# 6        They're taking adventure to new lengths.
# 7                             A New Age Has Come.
# 8                           Dark Secrets Revealed
# 9                              Justice or revenge
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124
# 5                              Spider-Man 3           5.9        3576
# 6                                   Tangled           7.4        3330
# 7                   Avengers: Age of Ultron           7.3        6767
# 8    Harry Potter and the Half-Blood Prince           7.4        5293
# 9        Batman v Superman: Dawn of Justice           5.7        7004

# %%
nan_values = dataset. isna()
nan_columns = nan_values. any()
nan_list = dataset.columns[nan_columns].tolist()

# %%
nan_list
# Out:
# ['homepage', 'overview', 'release_date', 'runtime', 'tagline']

# %%
print(dataset['homepage'].dtypes)
print(dataset['overview'].dtypes)
print(dataset['release_date'].dtypes)
print(dataset['runtime'].dtypes)
print(dataset['tagline'].dtypes)
# Out:
# object
# object
# object
# float64
# object

# %% [markdown]
# ##### Exploring data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize = (8, 4))
sns.boxplot(dataset['runtime'])
# Out:
# <AxesSubplot:xlabel='runtime'>

# %% [markdown]
# NOTE: As we can see the only numerical column with nan values has an outlier. so I cannot use mean

# %% [markdown]
# ### Check if any NANs in your dataset and fill them with a good filer ###

# %%
if dataset.isnull().values.any():
    dataset = dataset.apply(lambda df: df.fillna(df.value_counts().index[0])) # fill with the most frequent item
    # or just use the mode function
    #dataset = dataset.fillna(dataset.mode())

# %%
"""
We can fill the datasets by many ways. depending on the way we see the data. the filling method always depend on the 
understanding of the columns variables
"""
# mean is not always the best solution, if there is any outliers, it will be misleading. 
#more suitable with symmetric data distribution
"""dataset.fillna(dataset.mean(), inplace = True) """

# median is a good solution with skewed data. but since we have categoricals variables I cannot use it
"""dataset.fillna(dataset.median(), inplace = True)"""

# also we can use linear interpolation to fill the nan data,
# in this code snippet it will change the nan with the most suitable number, to follow the direction of increasing.
"""dataset.interpolate(method ='linear', limit_direction ='forward')"""
# Out:
# "dataset.interpolate(method ='linear', limit_direction ='forward')"

# %%
dataset.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Discover the types of each columns and modify them if needed ###

# %%
pd.DataFrame([dataset.dtypes])
#I see that there is no need to change any column type as the numeric is numeric and 
#categorical will always displayed as object
# Out:
#   budget  genres homepage     id keywords original_language original_title  \
# 0  int64  object   object  int64   object            object         object
#
#   overview popularity production_companies production_countries release_date  \
# 0   object    float64               object               object       object
#
#   revenue  runtime spoken_languages  status tagline   title vote_average  \
# 0   int64  float64           object  object  object  object      float64
#
#   vote_count
# 0      int64

# %% [markdown]
# ### Give a very simple statistical analsys for the numerical columns ###

# %%
dataset.describe().round()
# Out:
#             budget        id  popularity       revenue  runtime  vote_average  \
# count       4803.0    4803.0      4803.0  4.803000e+03   4801.0        4803.0
# mean    29045040.0   57165.0        21.0  8.226064e+07    107.0           6.0
# std     40722391.0   88695.0        32.0  1.628571e+08     23.0           1.0
# min            0.0       5.0         0.0  0.000000e+00      0.0           0.0
# 25%       790000.0    9014.0         5.0  0.000000e+00     94.0           6.0
# 50%     15000000.0   14629.0        13.0  1.917000e+07    103.0           6.0
# 75%     40000000.0   58610.0        28.0  9.291719e+07    118.0           7.0
# max    380000000.0  459488.0       876.0  2.787965e+09    338.0          10.0
#
#        vote_count
# count      4803.0
# mean        690.0
# std        1235.0
# min           0.0
# 25%          54.0
# 50%         235.0
# 75%         737.0
# max       13752.0

# %%
num_cols = dataset._get_numeric_data().columns # get the numeric columns
dataset[num_cols].describe().apply(lambda s: s.apply('{0:.5f}'.format)) # describe with removing the e notation
# Out:
#                 budget            id  popularity           revenue  \
# count       4803.00000    4803.00000  4803.00000        4803.00000
# mean    29045039.87529   57165.48428    21.49230    82260638.65168
# std     40722391.25855   88694.61403    31.81665   162857100.94283
# min            0.00000       5.00000     0.00000           0.00000
# 25%       790000.00000    9014.50000     4.66807           0.00000
# 50%     15000000.00000   14629.00000    12.92159    19170001.00000
# 75%     40000000.00000   58610.50000    28.31350    92917187.00000
# max    380000000.00000  459488.00000   875.58131  2787965087.00000
#
#           runtime vote_average   vote_count
# count  4801.00000   4803.00000   4803.00000
# mean    106.87586      6.09217    690.21799
# std      22.61193      1.19461   1234.58589
# min       0.00000      0.00000      0.00000
# 25%      94.00000      5.60000     54.00000
# 50%     103.00000      6.20000    235.00000
# 75%     118.00000      6.80000    737.00000
# max     338.00000     10.00000  13752.00000

# %% [markdown]
# ### Calculate the mean rate for [1999, 1980, 2004, 2017] the movies grouped by years ###

# %%
dataset.columns[nan_columns].to_list()
# Out:
# ['homepage', 'overview', 'release_date', 'runtime', 'tagline']

# %%
### Ex: Average Movies Rate at 2009 is 6.065587 ###
# initializing a temporary data frame with the specific columns for query
specific_year_df = pd.DataFrame()
specific_year_df[['year', 'month', 'day']] = dataset['release_date'].str.split('-', expand = True)
specific_year_df['vote_average'] = dataset['vote_average']

desired_years = list()
years = ['1999', '1980', '2004', '2017'] # 2009 is just a test case

for i in years:
    # calculating the mean rate and group by the year.
    desired_years.append(specific_year_df.loc[specific_year_df['year'] == i].groupby('year', as_index=True)['vote_average'].mean())
pd.concat(desired_years).reset_index()
# Out:
#    year  vote_average
# 0  1999      6.110526
# 1  1980      6.609091
# 2  2004      6.104412
# 3  2017      7.400000

# %%
specific_year_df
# Out:
#       year month day  vote_average
# 0     2009    12  10           7.2
# 1     2007    05  19           6.9
# 2     2015    10  26           6.3
# 3     2012    07  16           7.6
# 4     2012    03  07           6.1
# ...    ...   ...  ..           ...
# 4798  1992    09  04           6.6
# 4799  2011    12  26           5.9
# 4800  2013    10  13           7.0
# 4801  2012    05  03           5.7
# 4802  2005    08  05           6.3
#
# [4803 rows x 4 columns]

# %%
desired_years
# Out:
# [year
#  1999    6.110526
#  Name: vote_average, dtype: float64,
#  year
#  1980    6.609091
#  Name: vote_average, dtype: float64,
#  year
#  2004    6.104412
#  Name: vote_average, dtype: float64,
#  year
#  2017    7.4
#  Name: vote_average, dtype: float64]

# %% [markdown]
# ### Rearange the dataframe based on revenue - budget values ###

# %%
dataset.sort_values(by = ['revenue','budget'], ascending = True)
# Out:
#         budget                                             genres  \
# 265          0  [{"id": 35, "name": "Comedy"}, {"id": 14, "nam...
# 406          0  [{"id": 18, "name": "Drama"}, {"id": 16, "name...
# 453          0  [{"id": 28, "name": "Action"}, {"id": 35, "nam...
# 463          0  [{"id": 10749, "name": "Romance"}, {"id": 18, ...
# 474          0  [{"id": 9648, "name": "Mystery"}, {"id": 18, "...
# ..         ...                                                ...
# 44   190000000                     [{"id": 28, "name": "Action"}]
# 28   150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 16   220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 25   200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                               homepage      id  \
# 265  http://www.missionimpossible.com/   10588
# 406    http://www.arthurchristmas.com/   51052
# 453  http://www.missionimpossible.com/   12096
# 463  http://www.missionimpossible.com/  161795
# 474  http://www.missionimpossible.com/  330770
# ..                                 ...     ...
# 44            http://www.furious7.com/  168259
# 28       http://www.jurassicworld.com/  135397
# 16   http://marvel.com/avengers_movie/   24428
# 25         http://www.titanicmovie.com     597
# 0          http://www.avatarmovie.com/   19995
#
#                                               keywords original_language  \
# 265  [{"id": 977, "name": "cat"}, {"id": 1155, "nam...                en
# 406  [{"id": 65, "name": "holiday"}, {"id": 1991, "...                en
# 453  [{"id": 642, "name": "robbery"}, {"id": 5340, ...                en
# 463  [{"id": 9673, "name": "love"}, {"id": 14638, "...                en
# 474  [{"id": 428, "name": "nurse"}, {"id": 658, "na...                fr
# ..                                                 ...               ...
# 44   [{"id": 830, "name": "car race"}, {"id": 3428,...                en
# 28   [{"id": 1299, "name": "monster"}, {"id": 1718,...                en
# 16   [{"id": 242, "name": "new york"}, {"id": 5539,...                en
# 25   [{"id": 2580, "name": "shipwreck"}, {"id": 298...                en
# 0    [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#          original_title                                           overview  \
# 265  The Cat in the Hat  Conrad and Sally Walden are home alone with th...
# 406    Arthur Christmas  Each Christmas, Santa and his vast army of hig...
# 453    The Pink Panther  When the coach of the France soccer team is ki...
# 463             Déjà Vu  L.A. shop owner Dana and Englishman Sean meet ...
# 474           Évolution  11-year-old Nicolas lives with his mother in a...
# ..                  ...                                                ...
# 44            Furious 7  Deckard Shaw seeks revenge against Dominic Tor...
# 28       Jurassic World  Twenty-two years after the events of Jurassic ...
# 16         The Avengers  When an unexpected enemy emerges and threatens...
# 25              Titanic  84 years later, a 101-year-old woman named Ros...
# 0                Avatar  In the 22nd century, a paraplegic Marine is di...
#
#      popularity                               production_companies  \
# 265   18.251129  [{"name": "Imagine Entertainment", "id": 23}, ...
# 406   19.836830  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 453   25.450534  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 463    0.605645  [{"name": "Rainbow Film Company, The", "id": 2...
# 474    3.300061  [{"name": "Ex Nihilo", "id": 3307}, {"name": "...
# ..          ...                                                ...
# 44   102.322217  [{"name": "Universal Pictures", "id": 33}, {"n...
# 28   418.708552  [{"name": "Universal Studios", "id": 13}, {"na...
# 16   144.448633  [{"name": "Paramount Pictures", "id": 4}, {"na...
# 25   100.025899  [{"name": "Paramount Pictures", "id": 4}, {"na...
# 0    150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                   production_countries release_date  \
# 265  [{"iso_3166_1": "US", "name": "United States o...   2003-11-21
# 406  [{"iso_3166_1": "US", "name": "United States o...   2011-02-22
# 453  [{"iso_3166_1": "US", "name": "United States o...   2006-01-18
# 463  [{"iso_3166_1": "US", "name": "United States o...   1998-04-22
# 474  [{"iso_3166_1": "BE", "name": "Belgium"}, {"is...   2015-09-14
# ..                                                 ...          ...
# 44   [{"iso_3166_1": "JP", "name": "Japan"}, {"iso_...   2015-04-01
# 28   [{"iso_3166_1": "US", "name": "United States o...   2015-06-09
# 16   [{"iso_3166_1": "US", "name": "United States o...   2012-04-25
# 25   [{"iso_3166_1": "US", "name": "United States o...   1997-11-18
# 0    [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
#
#         revenue  runtime                                   spoken_languages  \
# 265           0     82.0           [{"iso_639_1": "en", "name": "English"}]
# 406           0     97.0           [{"iso_639_1": "en", "name": "English"}]
# 453           0     93.0           [{"iso_639_1": "en", "name": "English"}]
# 463           0    117.0           [{"iso_639_1": "en", "name": "English"}]
# 474           0     81.0     [{"iso_639_1": "fr", "name": "Fran\u00e7ais"}]
# ..          ...      ...                                                ...
# 44   1506249360    137.0           [{"iso_639_1": "en", "name": "English"}]
# 28   1513528810    124.0           [{"iso_639_1": "en", "name": "English"}]
# 16   1519557910    143.0           [{"iso_639_1": "en", "name": "English"}]
# 25   1845034188    194.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 0    2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
#
#        status                                            tagline  \
# 265  Released                           Don't mess with the hat.
# 406  Released  Ever wonder how 2 Billion presents get deliver...
# 453  Released                                 Pardon His French.
# 463  Released                              Your future is set...
# 474  Released                             Based on a true story.
# ..        ...                                                ...
# 44   Released                                Vengeance Hits Home
# 28   Released                                  The park is open.
# 16   Released                            Some assembly required.
# 25   Released          Nothing on Earth could come between them.
# 0    Released                        Enter the World of Pandora.
#
#                   title  vote_average  vote_count
# 265  The Cat in the Hat           4.9         366
# 406    Arthur Christmas           6.7         333
# 453    The Pink Panther           5.6         550
# 463             Déjà Vu           8.0           1
# 474           Evolution           6.4          47
# ..                  ...           ...         ...
# 44            Furious 7           7.3        4176
# 28       Jurassic World           6.5        8662
# 16         The Avengers           7.4       11776
# 25              Titanic           7.5        7562
# 0                Avatar           7.2       11800
#
# [4803 rows x 20 columns]

# %% [markdown]
# ### Allocate the year with the largest movies released in ['Action', 'Romance'] ###

# %%
import json

# %%
dataset['genres'][0]
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
json.loads(dataset['genres'][0])[0]['name']
# Out:
# 'Action'

# %%
dataset['release_date'].str.split('-')[0][0]
# Out:
# '2009'

# %%
year_df = pd.DataFrame()
year_df[['year', 'month', 'day']] = dataset['release_date'].str.split('-', expand = True)
year_df
# Out:
#       year month day
# 0     2009    12  10
# 1     2007    05  19
# 2     2015    10  26
# 3     2012    07  16
# 4     2012    03  07
# ...    ...   ...  ..
# 4798  1992    09  04
# 4799  2011    12  26
# 4800  2013    10  13
# 4801  2012    05  03
# 4802  2005    08  05
#
# [4803 rows x 3 columns]

# %%
# getting the columns to query in a temp dataframe
year_df = pd.DataFrame()
year_df[['year', 'month', 'day']] = dataset['release_date'].str.split('-', expand = True)

desired_genre = list()
for i in range(len(dataset)):
    temp = len(desired_genre)
    z = json.loads(dataset['genres'][i])
    for j in range(len(z)):
        x = z[j]
        if x['name'] == 'Romance' or x['name'] == 'Action':
            desired_genre.append(1)
            break
    if temp == len(desired_genre):
        desired_genre.append(0)
year_df['genre'] = desired_genre
x = year_df.groupby('year', as_index=False)['genre'].sum()
x
pd.DataFrame(x.max()).T
# Out:
#    year genre
# 0  2017   108

# %%
type(x.max())
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Find the movies with top 5 revenue - budget value ###

# %%
rev_bud_df = dataset.sort_values(by = ['revenue','budget'], ascending = False)
rev_bud_df[0:5]
# Out:
#        budget                                             genres  \
# 0   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25  200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 16  220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 28  150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44  190000000                     [{"id": 28, "name": "Action"}]
#
#                              homepage      id  \
# 0         http://www.avatarmovie.com/   19995
# 25        http://www.titanicmovie.com     597
# 16  http://marvel.com/avengers_movie/   24428
# 28      http://www.jurassicworld.com/  135397
# 44           http://www.furious7.com/  168259
#
#                                              keywords original_language  \
# 0   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 25  [{"id": 2580, "name": "shipwreck"}, {"id": 298...                en
# 16  [{"id": 242, "name": "new york"}, {"id": 5539,...                en
# 28  [{"id": 1299, "name": "monster"}, {"id": 1718,...                en
# 44  [{"id": 830, "name": "car race"}, {"id": 3428,...                en
#
#     original_title                                           overview  \
# 0           Avatar  In the 22nd century, a paraplegic Marine is di...
# 25         Titanic  84 years later, a 101-year-old woman named Ros...
# 16    The Avengers  When an unexpected enemy emerges and threatens...
# 28  Jurassic World  Twenty-two years after the events of Jurassic ...
# 44       Furious 7  Deckard Shaw seeks revenge against Dominic Tor...
#
#     popularity                               production_companies  \
# 0   150.437577  [{"name": "Ingenious Film Partners", "id": 289...
# 25  100.025899  [{"name": "Paramount Pictures", "id": 4}, {"na...
# 16  144.448633  [{"name": "Paramount Pictures", "id": 4}, {"na...
# 28  418.708552  [{"name": "Universal Studios", "id": 13}, {"na...
# 44  102.322217  [{"name": "Universal Pictures", "id": 33}, {"n...
#
#                                  production_countries release_date  \
# 0   [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 25  [{"iso_3166_1": "US", "name": "United States o...   1997-11-18
# 16  [{"iso_3166_1": "US", "name": "United States o...   2012-04-25
# 28  [{"iso_3166_1": "US", "name": "United States o...   2015-06-09
# 44  [{"iso_3166_1": "JP", "name": "Japan"}, {"iso_...   2015-04-01
#
#        revenue  runtime                                   spoken_languages  \
# 0   2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 25  1845034188    194.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 16  1519557910    143.0           [{"iso_639_1": "en", "name": "English"}]
# 28  1513528810    124.0           [{"iso_639_1": "en", "name": "English"}]
# 44  1506249360    137.0           [{"iso_639_1": "en", "name": "English"}]
#
#       status                                    tagline           title  \
# 0   Released                Enter the World of Pandora.          Avatar
# 25  Released  Nothing on Earth could come between them.         Titanic
# 16  Released                    Some assembly required.    The Avengers
# 28  Released                          The park is open.  Jurassic World
# 44  Released                        Vengeance Hits Home       Furious 7
#
#     vote_average  vote_count
# 0            7.2       11800
# 25           7.5        7562
# 16           7.4       11776
# 28           6.5        8662
# 44           7.3        4176

# %%
# Pandas

Names = dataset.sort_values(by = 'revenue',ascending = False)['title']
pd.DataFrame(Names.head(5).reset_index(drop = 'index'))
# Out:
#             title
# 0          Avatar
# 1         Titanic
# 2    The Avengers
# 3  Jurassic World
# 4       Furious 7

# %%
# Numpy

"""Get the top 5 revenue"""
index = dataset['revenue'].to_numpy().argsort()[::-1]
for i in range(0, 5):
    print(dataset.loc[index[i]]['title'])
# Out:
# Avatar
# Titanic
# The Avengers
# Jurassic World
# Furious 7

# %%
"""Get the top 5 budget"""
index = dataset['budget'].to_numpy().argsort()[::-1]
for i in range(0, 5):
    print(dataset.loc[index[i]]['title'])
# Out:
# Pirates of the Caribbean: On Stranger Tides
# Pirates of the Caribbean: At World's End
# Avengers: Age of Ultron
# Superman Returns
# John Carter

# %% [markdown]
# ### Find the year with the highest number of movies release ###

# %%
year_df.year = year_df['year'].astype(float)

# %%
new_df = pd.DataFrame(index = None)
new_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
new_df = pd.DataFrame(index = None)
new_df['year'] = np.unique(np.sort(year_df['year'].to_numpy()))
new_df['year_count'] = list(year_df['year'].sort_values().value_counts(sort = False))
new_df.nlargest(1, 'year_count')
# Out:
#     year  year_count
# 81  2009         247

# %% [markdown]
# ### Find the top 2 countries with the highest production movies number ###

# %%
from collections import Counter

countries = list()
for i in range(len(dataset)):
    z = json.loads(dataset['production_countries'][i])
    for i in range(len(z)):
        x = z[i]
        countries.append(x['name'])

country = [country for country in Counter(countries).most_common(2)] 
country

# counter seems to be like "group by"
# subtype of dictionary
#      Key       :     Value
# your_own_Value : Count_your_own_value
# Out:
# [('United States of America', 3956), ('United Kingdom', 636)]

# %% [markdown]
# ### Find the top 1 company with the highest production movies number ###

# %%
companies = list()
for i in range(len(dataset)):
    z = json.loads(dataset['production_companies'][i])
    for i in range(len(z)):
        x = z[i]
        companies.append(x['name'])
        
company = [company for company in Counter(companies).most_common(1)]
company[0][0]
# Out:
# 'Warner Bros.'

# %% [markdown]
# ### Is there any relation between the runtime and average vote value ### **

# %%
import seaborn as sns

# %%
# Pair plot
print(dataset['runtime'].corr(dataset['vote_average']))

corr_df = pd.DataFrame()
corr_df['runtime'] = dataset['runtime']
corr_df['vote_average'] = dataset['vote_average']

sns.pairplot(corr_df, height = 1.5, kind = 'hist')
# Out:
# 0.3745806769169492

# %%
"""
As we can see the correlation value is very low, as well as if we visualize the correlation between the two columns
we will find that there is no any positive or negative correlation
"""
# Out:
# '\nAs we can see the correlation value is very low, as well as if we visualize the correlation between the two columns\nwe will fin that there is no any positive or negative correlation\n'

# %%
# Pair plot
print(dataset['budget'].corr(dataset['revenue']))

corr_df = pd.DataFrame()
corr_df['budget'] = dataset['budget']
corr_df['revenue'] = dataset['revenue']

sns.pairplot(corr_df, height = 1.5, kind = 'hist')
# Out:
# 0.7308228569244614

# %% [markdown]
# ### Find the top 5 movies with the highest rate, and find if there anything common between them. ###

# %%
index = dataset['vote_average'].to_numpy().argsort()[::-1]

rate_lst = list()
for i in range(0, 5):
    print(dataset.loc[index[i]]['title'])
    rate_lst.append(dataset.loc[index[i]])
# Out:
# Little Big Top
# Me You and Five Bucks
# Dancer, Texas Pop. 81
# Stiff Upper Lips
# Sardaarji

# %%
high_rate_df = pd.DataFrame(rate_lst)
high_rate_df
# Out:
#       budget                                             genres  \
# 4662       0                     [{"id": 35, "name": "Comedy"}]
# 4247       1  [{"id": 10749, "name": "Romance"}, {"id": 35, ...
# 4045       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3519       0                     [{"id": 35, "name": "Comedy"}]
# 3992       0                                                 []
#
#                                homepage      id  \
# 4662  http://www.missionimpossible.com/   40963
# 4247  http://www.missionimpossible.com/  361505
# 4045  http://www.missionimpossible.com/   78373
# 3519  http://www.missionimpossible.com/   89861
# 3992  http://www.missionimpossible.com/  346081
#
#                                                keywords original_language  \
# 4662        [{"id": 10183, "name": "independent film"}]                en
# 4247                                                 []                en
# 4045  [{"id": 1415, "name": "small town"}, {"id": 15...                en
# 3519  [{"id": 131, "name": "italy"}, {"id": 8250, "n...                en
# 3992                                                 []                en
#
#              original_title  \
# 4662         Little Big Top
# 4247  Me You and Five Bucks
# 4045  Dancer, Texas Pop. 81
# 3519       Stiff Upper Lips
# 3992              Sardaarji
#
#                                                overview  popularity  \
# 4662  An aging out of work clown returns to his smal...    0.092100
# 4247  A womanizing yet lovable loser, Charlie, a wai...    0.094105
# 4045  Four guys, best friends, have grown up togethe...    0.376662
# 3519  Stiff Upper Lips is a broad parody of British ...    0.356495
# 3992  A ghost hunter uses bottles to capture trouble...    0.296981
#
#                                    production_companies  \
# 4662          [{"name": "Fly High Films", "id": 24248}]
# 4247                                                 []
# 4045  [{"name": "HSX Films", "id": 4714}, {"name": "...
# 3519                                                 []
# 3992                                                 []
#
#                                    production_countries release_date  revenue  \
# 4662  [{"iso_3166_1": "US", "name": "United States o...   2006-01-01        0
# 4247                                                 []   2015-07-07        0
# 4045  [{"iso_3166_1": "US", "name": "United States o...   1998-05-01   565592
# 3519  [{"iso_3166_1": "GB", "name": "United Kingdom"...   1998-06-12        0
# 3992            [{"iso_3166_1": "IN", "name": "India"}]   2015-06-26        0
#
#       runtime                          spoken_languages    status  \
# 4662      0.0  [{"iso_639_1": "en", "name": "English"}]   Rumored
# 4247     90.0                                        []  Released
# 4045     97.0  [{"iso_639_1": "en", "name": "English"}]  Released
# 3519     99.0  [{"iso_639_1": "en", "name": "English"}]  Released
# 3992      0.0                                        []  Released
#
#                                            tagline                  title  \
# 4662                        Based on a true story.         Little Big Top
# 4247          A story about second, second chances  Me You and Five Bucks
# 4045  in the middle of nowhere they had everything  Dancer, Texas Pop. 81
# 3519                        Based on a true story.       Stiff Upper Lips
# 3992                        Based on a true story.              Sardaarji
#
#       vote_average  vote_count
# 4662          10.0           1
# 4247          10.0           2
# 4045          10.0           1
# 3519          10.0           1
# 3992           9.5           2

# %%
import matplotlib.pyplot as plt

# %%
# analysis base on the tagline

fig, ax = plt.subplots(figsize=(15, 4))

plt.bar(high_rate_df['tagline'].unique(), high_rate_df['tagline'].value_counts()) # (X-Axis, Y-Axis )

plt.title('tagline count', fontsize = 'x-large') # Full Plot
plt.ylabel('Count', fontsize = 'x-large') # y-axis name
plt.xlabel('Tagline', fontsize = 'x-large') # x-axis name
plt.show()

# %%
# Analysis based on the Genre

genres_corr = list()
for j in range(len(high_rate_df)):
    z = json.loads(high_rate_df['genres'].iloc[j])
    for i in range(len(z)):
        x = z[i]
        genres_corr.append(z[i]['name'])
temp_df = pd.DataFrame(genres_corr)
temp_df
# Out:
#          0
# 0   Comedy
# 1  Romance
# 2   Comedy
# 3    Drama
# 4   Comedy
# 5    Drama
# 6   Family
# 7   Comedy

# %%
fig, ax = plt.subplots(figsize=(15, 4))

plt.bar(temp_df[0].unique(), temp_df.value_counts())

plt.title('Genres count', fontsize = 'x-large')
plt.ylabel('Count', fontsize = 'x-large')
plt.xlabel('Genres', fontsize = 'x-large')
plt.show()

# %%
"""
It appears that there are 3 of the 5 movies depends on a true stroy, 4 of them have a comedy genre and 2 have romance.
So, it seems that the audience prefer the true stories that envolve Comedy and Romantic stories.
"""
# Out:
# '\nIt appears that there are 3 of the 5 movies depends on a true stroy, 4 of them have a comedy genre and 2 have romance.\nSo, it seems that the audience prefer the true stories that envolve Comedy and Romantic stories.\n'

# %% [markdown]
# ### Find the most unsuccessful movie along time in terms of revenue - budget ###

# %%
x = dataset.sort_values(by = ['revenue', 'budget'], ascending = True, ignore_index = True )
x['title'][0]
# Out:
# 'The Cat in the Hat'

# %% [markdown]
# ### Rearange the dataframe based on vote_average column values ###

# %%
dataset.sort_values(by = ['vote_average'], ascending = True)
# Out:
#       budget                                             genres  \
# 4633       0                                                 []
# 4305       0  [{"id": 35, "name": "Comedy"}, {"id": 10402, "...
# 4653       0                      [{"id": 18, "name": "Drama"}]
# 4293       1                                                 []
# 4118       0                                                 []
# ...      ...                                                ...
# 3992       0                                                 []
# 3519       0                     [{"id": 35, "name": "Comedy"}]
# 4045       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4247       1  [{"id": 10749, "name": "Romance"}, {"id": 35, ...
# 4662       0                     [{"id": 35, "name": "Comedy"}]
#
#                                homepage      id  \
# 4633  http://www.missionimpossible.com/  300327
# 4305  http://www.missionimpossible.com/  114065
# 4653  http://www.missionimpossible.com/   46252
# 4293       http://thealgerianmovie.com/  357834
# 4118  http://www.missionimpossible.com/  325140
# ...                                 ...     ...
# 3992  http://www.missionimpossible.com/  346081
# 3519  http://www.missionimpossible.com/   89861
# 4045  http://www.missionimpossible.com/   78373
# 4247  http://www.missionimpossible.com/  361505
# 4662  http://www.missionimpossible.com/   40963
#
#                                                keywords original_language  \
# 4633                                                 []                en
# 4305                                                 []                en
# 4653                                                 []                en
# 4293                                                 []                en
# 4118                                                 []                en
# ...                                                 ...               ...
# 3992                                                 []                en
# 3519  [{"id": 131, "name": "italy"}, {"id": 8250, "n...                en
# 4045  [{"id": 1415, "name": "small town"}, {"id": 15...                en
# 4247                                                 []                en
# 4662        [{"id": 10183, "name": "independent film"}]                en
#
#                  original_title  \
# 4633                Death Calls
# 4305  Down & Out With The Dolls
# 4653                       Rust
# 4293               The Algerian
# 4118     Hum To Mohabbat Karega
# ...                         ...
# 3992                  Sardaarji
# 3519           Stiff Upper Lips
# 4045      Dancer, Texas Pop. 81
# 4247      Me You and Five Bucks
# 4662             Little Big Top
#
#                                                overview  popularity  \
# 4633  An action-packed love story on the Mexican bor...    0.005883
# 4305  The raunchy, spunky tale of the rise and fall ...    0.002386
# 4653  In the midst of a midlife crisis of faith, a m...    0.399491
# 4293  The Algerian is an international political thr...    0.025364
# 4118  Raju, a waiter, is in love with the famous TV ...    0.001186
# ...                                                 ...         ...
# 3992  A ghost hunter uses bottles to capture trouble...    0.296981
# 3519  Stiff Upper Lips is a broad parody of British ...    0.356495
# 4045  Four guys, best friends, have grown up togethe...    0.376662
# 4247  A womanizing yet lovable loser, Charlie, a wai...    0.094105
# 4662  An aging out of work clown returns to his smal...    0.092100
#
#                                    production_companies  \
# 4633                                                 []
# 4305                                                 []
# 4653                                                 []
# 4293             [{"name": "Zelko Films", "id": 62451}]
# 4118                                                 []
# ...                                                 ...
# 3992                                                 []
# 3519                                                 []
# 4045  [{"name": "HSX Films", "id": 4714}, {"name": "...
# 4247                                                 []
# 4662          [{"name": "Fly High Films", "id": 24248}]
#
#                                    production_countries release_date  revenue  \
# 4633                                                 []   2010-09-01        0
# 4305                                                 []   2003-03-20        0
# 4653                                                 []   2010-10-07        0
# 4293  [{"iso_3166_1": "DZ", "name": "Algeria"}, {"is...   2015-08-07        0
# 4118                                                 []   2000-05-26        0
# ...                                                 ...          ...      ...
# 3992            [{"iso_3166_1": "IN", "name": "India"}]   2015-06-26        0
# 3519  [{"iso_3166_1": "GB", "name": "United Kingdom"...   1998-06-12        0
# 4045  [{"iso_3166_1": "US", "name": "United States o...   1998-05-01   565592
# 4247                                                 []   2015-07-07        0
# 4662  [{"iso_3166_1": "US", "name": "United States o...   2006-01-01        0
#
#       runtime                          spoken_languages    status  \
# 4633      0.0                                        []  Released
# 4305     88.0                                        []  Released
# 4653     94.0                                        []  Released
# 4293     99.0                                        []  Released
# 4118      0.0                                        []  Released
# ...       ...                                       ...       ...
# 3992      0.0                                        []  Released
# 3519     99.0  [{"iso_639_1": "en", "name": "English"}]  Released
# 4045     97.0  [{"iso_639_1": "en", "name": "English"}]  Released
# 4247     90.0                                        []  Released
# 4662      0.0  [{"iso_639_1": "en", "name": "English"}]   Rumored
#
#                                            tagline                      title  \
# 4633                        Based on a true story.                Death Calls
# 4305                  Ain't Rock 'N' Roll a bitch.  Down & Out With The Dolls
# 4653                        Based on a true story.                       Rust
# 4293                        Based on a true story.               The Algerian
# 4118                        Based on a true story.     Hum To Mohabbat Karega
# ...                                            ...                        ...
# 3992                        Based on a true story.                  Sardaarji
# 3519                        Based on a true story.           Stiff Upper Lips
# 4045  in the middle of nowhere they had everything      Dancer, Texas Pop. 81
# 4247          A story about second, second chances      Me You and Five Bucks
# 4662                        Based on a true story.             Little Big Top
#
#       vote_average  vote_count
# 4633           0.0           0
# 4305           0.0           0
# 4653           0.0           0
# 4293           0.0           0
# 4118           0.0           0
# ...            ...         ...
# 3992           9.5           2
# 3519          10.0           1
# 4045          10.0           1
# 4247          10.0           2
# 4662          10.0           1
#
# [4803 rows x 20 columns]

# %% [markdown]
# ### Rearange the dataframe based on runtime column values ###

# %%
dataset.sort_values(by = ['runtime'], ascending = True)
# Out:
#         budget                                             genres  \
# 4620         0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 4658         0  [{"id": 27, "name": "Horror"}, {"id": 53, "nam...
# 3669         0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3809   4000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 3112         0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# ...        ...                                                ...
# 2373         0                      [{"id": 18, "name": "Drama"}]
# 1125  31115000  [{"id": 18, "name": "Drama"}, {"id": 36, "name...
# 1922         0  [{"id": 10752, "name": "War"}, {"id": 18, "nam...
# 2631         0                      [{"id": 18, "name": "Drama"}]
# 2384  18000000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
#
#                                homepage      id  \
# 4620  http://www.missionimpossible.com/   47534
# 4658  http://www.missionimpossible.com/  150211
# 3669      http://www.romeothemovie.com/  113406
# 3809  http://www.missionimpossible.com/  158150
# 3112  http://www.missionimpossible.com/   41894
# ...                                 ...     ...
# 2373  http://www.missionimpossible.com/   10549
# 1125  http://www.missionimpossible.com/    8095
# 1922  http://www.missionimpossible.com/   10655
# 2631  http://www.missionimpossible.com/  112430
# 2384  http://www.missionimpossible.com/   43434
#
#                                                keywords original_language  \
# 4620  [{"id": 2792, "name": "boxer"}, {"id": 4076, "...                en
# 4658  [{"id": 177972, "name": "bickering"}, {"id": 2...                en
# 3669                                                 []                en
# 3809                                                 []                en
# 3112                                                 []                en
# ...                                                 ...               ...
# 2373  [{"id": 456, "name": "mother"}, {"id": 497, "n...                en
# 1125  [{"id": 5049, "name": "ancient rome"}, {"id": ...                en
# 1922  [{"id": 393, "name": "civil war"}, {"id": 4097...                en
# 2631              [{"id": 11162, "name": "miniseries"}]                en
# 2384  [{"id": 1419, "name": "gun"}, {"id": 7336, "na...                en
#
#                original_title  \
# 4620     Fighting Tommy Riley
# 4658               The Frozen
# 3669     Should've Been Romeo
# 3809      How to Fall in Love
# 3112  Blood Done Sign My Name
# ...                       ...
# 2373                   Hamlet
# 1125                Cleopatra
# 1922               Gettysburg
# 2631              The Company
# 2384                   Carlos
#
#                                                overview  popularity  \
# 4620  An aging trainer and a young fighter, both in ...    0.045429
# 4658  After a harrowing snowmobile accident, a young...    1.084387
# 3669  A self-centered, middle-aged pitchman for a po...    0.407030
# 3809  An accountant, who never quite grew out of his...    1.923514
# 3112  A drama based on the true story in which a bla...    0.397341
# ...                                                 ...         ...
# 2373  Hamlet, Prince of Denmark, returns home to fin...    9.814785
# 1125  Historical epic. The triumphs and tragedy of t...   13.244365
# 1922  Summer 1863. The Confederacy pushes north into...    5.529035
# 2631  Real-life figures from the Cold War era mix wi...    1.485324
# 2384  The story of Venezuelan revolutionary, Ilich R...    1.138383
#
#                                    production_companies  \
# 4620                                                 []
# 4658                                                 []
# 3669       [{"name": "Phillybrook Films", "id": 65147}]
# 3809  [{"name": "Annuit Coeptis Entertainment Inc.",...
# 3112                                                 []
# ...                                                 ...
# 2373  [{"name": "Castle Rock Entertainment", "id": 9...
# 1125  [{"name": "Twentieth Century Fox Film Corporat...
# 1922  [{"name": "TriStar Television", "id": 8609}, {...
# 2631                                                 []
# 2384  [{"name": "Egoli Tossell Film AG", "id": 2254}...
#
#                                    production_countries release_date  \
# 4620                                                 []   2005-05-06
# 4658                                                 []   2012-10-10
# 3669  [{"iso_3166_1": "US", "name": "United States o...   2012-04-28
# 3809  [{"iso_3166_1": "US", "name": "United States o...   2012-07-21
# 3112                                                 []   2010-02-01
# ...                                                 ...          ...
# 2373  [{"iso_3166_1": "GB", "name": "United Kingdom"...   1996-12-25
# 1125  [{"iso_3166_1": "GB", "name": "United Kingdom"...   1963-06-12
# 1922  [{"iso_3166_1": "US", "name": "United States o...   1993-10-08
# 2631                                                 []   2007-08-05
# 2384  [{"iso_3166_1": "FR", "name": "France"}, {"iso...   2010-05-19
#
#        revenue  runtime                                   spoken_languages  \
# 4620         0      0.0           [{"iso_639_1": "en", "name": "English"}]
# 4658         0      0.0                                                 []
# 3669         0      0.0           [{"iso_639_1": "en", "name": "English"}]
# 3809         0      0.0           [{"iso_639_1": "en", "name": "English"}]
# 3112         0      0.0                                                 []
# ...        ...      ...                                                ...
# 2373         0    242.0           [{"iso_639_1": "en", "name": "English"}]
# 1125  71000000    248.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1922  25000000    254.0           [{"iso_639_1": "en", "name": "English"}]
# 2631         0    276.0                                                 []
# 2384    871279    338.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
#
#         status                                            tagline  \
# 4620  Released                             Based on a true story.
# 4658  Released                             Based on a true story.
# 3669  Released       Even Shakespeare didn't see this one coming.
# 3809  Released                             Based on a true story.
# 3112  Released                    No one changes the world alone.
# ...        ...                                                ...
# 2373  Released                             Based on a true story.
# 1125  Released  The motion picture the world has been waiting ...
# 1922  Released                             Based on a true story.
# 2631  Released                             Based on a true story.
# 2384  Released                     The man who hijacked the world
#
#                         title  vote_average  vote_count
# 4620     Fighting Tommy Riley           5.3           4
# 4658               The Frozen           4.2          14
# 3669     Should've Been Romeo           0.0           0
# 3809      How to Fall in Love           5.2          20
# 3112  Blood Done Sign My Name           6.0           5
# ...                       ...           ...         ...
# 2373                   Hamlet           7.3         117
# 1125                Cleopatra           6.7         146
# 1922               Gettysburg           6.6          90
# 2631              The Company           7.0          12
# 2384                   Carlos           6.7          50
#
# [4803 rows x 20 columns]

# %% [markdown]
# ### Find the top 5 successful years for the USA cinema based on the total income devided by number of movies  ###

# %%
top_year_df = pd.DataFrame()
top_year_df[['year', 'month', 'day']] = dataset['release_date'].str.split('-', expand = True)
top_year_df['revenue'] = dataset['revenue']
top_year_df['budget'] = dataset['budget']

x = top_year_df.groupby('year', as_index=False)[['revenue', 'budget']].sum()
x['income'] = x['revenue'] - x['budget']

x = x.sort_values(by = ['income'], ascending = False)

x.iloc[:5]
# Out:
#     year      revenue      budget       income
# 84  2012  24141710246  7263782654  16877927592
# 86  2014  24120490589  7368453311  16752037278
# 87  2015  22775024221  6724547367  16050476854
# 85  2013  23411493295  8205880834  15205612461
# 81  2009  21072651506  7644466762  13428184744

# %% [markdown]
# ### Find the most succesfull movie in [USA, UK] ###

# %%
## the most successful movie based on income

movie_df = top_year_df.copy()
movie_df['movie_name'] = dataset['title']
movie_df['rate'] = dataset['vote_average']
movie_df['income'] = movie_df['revenue'] - movie_df['budget'] # Derived Column

desired_country = list()
for i in range(len(dataset)):
    temp = len(desired_country)
    z = json.loads(dataset['production_countries'][i])
    temp_country_ls = list()
    for j in range(len(z)):
        x = z[j]
        temp_country_ls.append(x['name'])
#         if x['name'] == 'United Kingdom' and x['name'] == 'United States':
#             desired_country.append(1)
#             break
    if 'United Kingdom' in temp_country_ls and 'United States of America' in temp_country_ls:
        desired_country.append(1)
    else: desired_country.append(0)

movie_df['Uk-Us'] = desired_country
x = movie_df.sort_values(by = ['income'], ascending = False)
x.iloc[:1]['movie_name']
# Out:
# 0    Avatar
# Name: movie_name, dtype: object

# %%
## the most successful movie based on rate
movie_df = top_year_df.copy()
movie_df['movie_name'] = dataset['title']
movie_df['rate'] = dataset['vote_average']
movie_df['income'] = movie_df['revenue'] - movie_df['budget']

desired_country = list()
for i in range(len(dataset)):
    temp = len(desired_country)
    z = json.loads(dataset['production_countries'][i])
    temp_country_ls = list()
    for j in range(len(z)):
        x = z[j]
        temp_country_ls.append(x['name'])
#         if x['name'] == 'United Kingdom' and x['name'] == 'United States':
#             desired_country.append(1)
#             break
    if 'United Kingdom' in temp_country_ls and 'United States of America' in temp_country_ls:
        desired_country.append(1)
    else: desired_country.append(0)

movie_df['Uk-Us'] = desired_country
x = movie_df.sort_values(by = ['rate'], ascending = False)
x.iloc[:1]['movie_name']
# Out:
# 3519    Stiff Upper Lips
# Name: movie_name, dtype: object

# %% [markdown]
# ### In your opinion what is the highest variable that affects the revenue value (high coloration) ### BONUS

# %%
# you should drop id column

plt.figure(figsize=(8,8))

sns.heatmap(dataset.corr(), annot = True, cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
"""
As the correlation map implies. there are two variables affect the revenue ("vote_count", "budget").

I beleive that as the budget increase the more likely the movie become better and have more population 
may be due to more puplication. and that cause more votes.
"""
# Out:
# '\nAs the correlation map implies. there are two variables affect the revenue ("vote_count", "budget").\nI beleive that as the budget increase the more likely the movie become better and have more population \nmay be due to more puplication. and that cause more votes.\n'

# %% [markdown]
# ## Good Luck
